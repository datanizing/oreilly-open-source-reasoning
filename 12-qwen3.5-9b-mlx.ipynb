# %% [markdown]
# # Run a Qwen3.5 reasoning model on Apple Silicon
#
# The previous notebook was optimized for GPUs (using CUDA). If you want to run models on your Mac,
# that hardware is also well-suited for reasoning LLMs.
#
# Apple developed their own framework ([mlx](https://github.com/ml-explore/mlx)). This is a very
# nice framework which can also be accessed via Python.
#
# Apple hardware is particularly well-suited for running LLMs as the memory bandwidth is higher
# compared to PCs.  `mlx` is optimized for Apple Silicon and allows running models very quickly,
# especially if you use quantized models.

# %% [markdown]
# We will use the same model as before on the GPU, i.e.
# [XiaomiMiMo/MiMo-V2.6-Distill-Qwen-9B](https://huggingface.co/XiaomiMiMo/MiMo-V2.6-Distill-Qwen-9B).
#
# However, models in `mlx` come in a different (optimized) format, therefore the model name changes to
# here changes to [mlx-community/MiMo-V2.6-Distill-Qwen-9B-OptiQ-4bit](https://huggingface.co/mlx-community/MiMo-V2.6-Distill-Qwen-9B-OptiQ-4bit).

# %% [markdown]
# The interface is completely different from `transformers`.

# %%
from mlx_lm import load, generate

# %% [markdown]
# Quite comfortable: `model` and `tokenizer` are returned as a pair

# %%
model, tokenizer = load("mlx-community/MiMo-V2.6-Distill-Qwen-9B-OptiQ-4bit")
# Out:
# Downloading bytes:           |  0.00B
# Reconstructing (incomplete total...): |          |  0.00B /  0.00B
# Fetching 9 files:   0%|          | 0/9 [00:00<?, ?it/s]

# %%
prompt = "How many 'r's are in 'strawberry'?"

# %% [markdown]
# `apply_chat_template` also exists in the `tokenizer`, similar to Hugging Face `transformers`.

# %%
if tokenizer.chat_template is not None:
    messages = [{"role": "user", "content": prompt}]
    prompt = tokenizer.apply_chat_template(
        messages, add_generation_prompt=True
    )

# %% [markdown]
# Generation works also in a very similar way, but streaming output is directly shown.

# %%
response = generate(model, tokenizer, prompt=prompt, verbose=True, max_tokens=2500)
# Out:
# ==========
# <think>The user asks how many 'r's are in "strawberry". Let me count: s-t-r-a-w-b-e-r-r-y. That's positions 3, 8, 9. So 3 r's.</think>There are **3** "r"s in "strawberry":
#
# - s-t-**r**-a-w-b-e-**r**-**r**-y
# ==========
# Prompt: 19 tokens, 8.271 tokens-per-sec
# Generation: 83 tokens, 80.306 tokens-per-sec
# Peak memory: 7.263 GB

# %% [markdown]
# The response variable contains the whole string:

# %%
print(response)
# Out:
# <think>The user asks how many 'r's are in "strawberry". Let me count: s-t-r-a-w-b-e-r-r-y. That's positions 3, 8, 9. So 3 r's.</think>There are **3** "r"s in "strawberry":
#
# - s-t-**r**-a-w-b-e-**r**-**r**-y

# %%
from IPython.display import display, Markdown
display(Markdown(response))
# Out:
# <think>The user asks how many 'r's are in "strawberry". Let me count: s-t-r-a-w-b-e-r-r-y. That's positions 3, 8, 9. So 3 r's.</think>There are **3** "r"s in "strawberry":
#
# - s-t-**r**-a-w-b-e-**r**-**r**-y
